# %%
# 876. Middle of the Linked List

class ListNode(object):
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next
class Solution(object):
    def middleNode(self, head):
        f=s=head
        while f is not None and f.next is not None:
            s=s.next
            f=f.next.next
        return s
    
ListNode1 = ListNode(1)
ListNode2 = ListNode(2)
ListNode3 = ListNode(3)
ListNode4 = ListNode(4)
ListNode5 = ListNode(5)
Solution = Solution()
ListNode1.next = ListNode2
ListNode2.next = ListNode3
ListNode3.next = ListNode4
ListNode4.next = ListNode5
print(Solution.middleNode(ListNode1).val)  # Output: 3
# Out:
# 3

# %%
# 141. Linked List Cycle Brute Force 
class ListNode(object):
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next
        
def hasCycle(self, head):
        c = head
        s = set()
        while c:
            if c in s:
                return True
            s.add(c)
            c = c.next
        return False

# %%
# 141. Linked List Cycle Optimal Code
class ListNode(object):
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next
        
class Solution(object):
    def hasCycle(self, head):
        f=s=head
        while f is not None and f.next is not None:
            s=s.next
            f=f.next.next
            if f==s:
                return True
        return False
ListNode1 = ListNode(1)
ListNode2 = ListNode(2)
ListNode3 = ListNode(3)
ListNode4 = ListNode(4)
ListNode5 = ListNode(5)
Solution = Solution()
ListNode1.next = ListNode2
ListNode2.next = ListNode3
ListNode3.next = ListNode4
ListNode4.next = ListNode5
Solution.hasCycle(ListNode1)  # Output: False

# %%
# 142. Linked List Cycle II Node value return

class Solution(object):
    def detectCycle(self, head):
        f = s = head
        while f is not None and f.next is not None:
            s = s.next
            f = f.next.next
            if s == f:
                break
        else:
            return None

        s = head
        while s != f:
            s = s.next
            f = f.next

        return s

# %%
# 19. Remove Nth Node From End of List

class Solution(object):

    def removeNthFromEnd(self, head, n):
        d = ListNode(0)
        d.next = head
        fast = slow = d
        for _ in range(n + 1):
            fast = fast.next
        while fast:
            fast = fast.next
            slow = slow.next
        slow.next = slow.next.next
        return d.next
